# %%
name = input("What is your name")
while(True):
    try:
        age = int(input("what is your age"))
        break
    except:
        print("Not valid, try again")
          
print(f"you are {name} and you are {age} years old")
# Out:
# What is your name kosi
# what is your age 5
# you are kosi and you are 5 years old
